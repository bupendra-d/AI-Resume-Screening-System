# %% [markdown]
# # Predict Resume Category Function Testing

# %%
from src.predictor import predict_resume_category

# %%
# Test 1
prediction = predict_resume_category(
    "sample_resumes/teacher.pdf"
)

# Top 3 Matches
print(prediction[1])
# Out:
# ['TEACHER', 'ARTS', 'DESIGNER']

# %%
# Test 2
prediction = predict_resume_category(
    "sample_resumes/software_engineer.pdf"
)

# Top 3 Matches
print(prediction[1])
# Out:
# ['ENGINEERING', 'BUSINESS-DEVELOPMENT', 'CONSULTANT']
